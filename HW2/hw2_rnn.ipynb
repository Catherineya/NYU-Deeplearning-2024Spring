# %% [markdown]
# # Homework 2 - Recurrent Neural Networks

# %% [markdown]
# In this part of the homework we are going to work with Recurrent Neural Networks, in particular GRU. One of the greatest things that Recurrent Neural Networks can do when working with sequences is retaining data from several timesteps in the past. We are going to explore that property by constructing an 'echo' Recurrent Neural Network.
#
# The goal here is to make a model that given a sequence of letters or digits will output that same sequence, but with a certain delay. Let's say the input is a string 'abacaba', we want the model to not output anything for 3 steps (delay length), and then output the original string step by step, except the last 3 characters. So, target output is then 'XXXabac', where 'X' is empty output.
#
# This is similar to [this notebook](https://github.com/Atcold/pytorch-Deep-Learning/blob/master/09-echo_data.ipynb) (which you should refer to when doing this assignment), except we're working not with a binary string, but with a sequence of integers between 0 and some N. In our case N is 26, which is the number of letters in the alphabet.

# %% [markdown]
# ## Dataset
#
# Let's implement the dataset. In our case, the data is basically infinite, as we can always generate more examples on the fly, so there's no need to load it from disk.

# %%
import random
import string

import torch

# Max value of the generated integer. 26 is chosen becuase it's
# the number of letters in English alphabet.
N = 26


def idx_to_onehot(x, k=N+1):
  """ Converts the generated integers to one-hot vectors """
  ones = torch.sparse.torch.eye(k)
  shape = x.shape
  res = ones.index_select(0, x.view(-1).type(torch.int64))
  return res.view(*shape, res.shape[-1])


class EchoDataset(torch.utils.data.IterableDataset):

  def __init__(self, delay=4, seq_length=15, size=1000):
    self.delay = delay
    self.seq_length = seq_length
    self.size = size

  def __len__(self):
    return self.size

  def __iter__(self):
    """ Iterable dataset doesn't have to implement __getitem__.
        Instead, we only need to implement __iter__ to return
        an iterator (or generator).
    """
    for _ in range(self.size):
      seq = torch.tensor([random.choice(range(1, N + 1)) for i in range(self.seq_length)], dtype=torch.int64)
      result = torch.cat((torch.zeros(self.delay), seq[:self.seq_length - self.delay])).type(torch.int64)
      yield seq, result

DELAY = 4
DATASET_SIZE = 200000
ds = EchoDataset(delay=DELAY, size=DATASET_SIZE)

# %% [markdown]
# ## Model
#
# Now, we want to implement the model. For our purposes, we want to use GRU. The architecture consists of GRU and a decoder. Decoder is responsible for decoding the GRU hidden state to yield a predicting for the next output. The parts you are responsible for filling with your code are marked with `TODO`.

# %%
class GRUMemory(torch.nn.Module):

  def __init__(self, hidden_size):
    super().__init__()
    #TODO: initialize your submodules
    self.gru = torch.nn.GRU(N + 1, hidden_size, num_layers=1, batch_first=True)
    self.decoder = torch.nn.Linear(hidden_size, N+1)
    self.hidden = None

  def forward(self, x):
    # inputs: x - input tensor of shape (batch_size, seq_length, N+1)
    # returns:
    # logits (scores for softmax) of shape (batch size, seq_length, N + 1)
    # TODO implement forward pass
    output, _ = self.gru(x)
    logits = self.decoder(output)
    return logits

  @torch.no_grad()
  def test_run(self, s):
    # This function accepts one string s containing lowercase characters a-z.
    # You need to map those characters to one-hot encodings,
    # then get the result from your network, and then convert the output
    # back to a string of the same length, with 0 mapped to ' ',
    # and 1-26 mapped to a-z.

    # TODO
    s = [(ord(c) - ord('a') + 1) for c in s]
    onehot = idx_to_onehot(torch.tensor(s, dtype=torch.int64)).unsqueeze(0).to(next(self.parameters()).device)
    logits = self.forward(onehot)
    pred = torch.argmax(logits, dim=2)
    pred = pred.squeeze(0)

    pred_str = ''.join([' ' if c == 0 else chr(c + ord('a') - 1) for c in pred])
    return pred_str

# %% [markdown]
# ## Training
# Below you need to implement the training of the model. We give you more freedom as for the implementation. The two limitations are that it has to execute within 10 minutes, and that error rate should be below 1%.

# %%
D=4
def test_model(model, sequence_length=15):
  """
  This is the test function that runs 100 different strings through your model,
  and checks the error rate.
  """
  total = 0
  correct = 0
  for i in range(500):
    s = ''.join([random.choice(string.ascii_lowercase) for i in range(random.randint(15, 25))])
    result = model.test_run(s)
    for c1, c2 in zip(s[:-D], result[D:]):
      correct += int(c1 == c2)
    total += len(s) - D

  return correct / total

# %%
import time
import torch
from torch.utils.data import DataLoader
# Assuming GRUMemory, EchoDataset, and idx_to_onehot are defined elsewhere

start_time = time.time()

gru_model = GRUMemory(hidden_size=128)  # Use 'gru_model' instead of 'model' to avoid confusion
optimizer = torch.optim.Adam(gru_model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
criterion = torch.nn.CrossEntropyLoss()  # Use 'criterion' for the loss function

ds = EchoDataset(delay=4, size=10000)
train_dataloader = DataLoader(ds, batch_size=64, num_workers=2, shuffle=False)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
gru_model.to(device)

epoch = 0
test_acc = 0

while test_acc <= 0.99:
    gru_model.train()
    for x, y in train_dataloader:
        x, y = x.to(device), y.to(device)
        x_onehot, y_onehot = idx_to_onehot(x), idx_to_onehot(y)

        optimizer.zero_grad()
        logits = gru_model(x_onehot)[:, 4:, :]
        y_target = y[:, 4:]
        loss_value = criterion(logits.reshape(-1, logits.size(-1)), y_target.reshape(-1))
        loss_value.backward()
        torch.nn.utils.clip_grad_norm_(gru_model.parameters(), 0.01)
        optimizer.step()

    scheduler.step()
    test_acc = test_model(gru_model)
    print(f'Epoch {epoch}: Test Accuracy: {test_acc}, Loss: {loss_value.item()}')
    epoch += 1

    # Time and accuracy checks
    duration = time.time() - start_time
    assert duration < 600, f'Execution took {duration:.2f} seconds, which is longer than 10 mins'
    assert test_acc > 0.99, f'Accuracy is too low, got {test_acc}, need 0.99'

print('Tests passed')
# Out:
# Epoch 0: Test Accuracy: 0.9926194645984489, Loss: 0.022024942561984062
# Tests passed

# %% [markdown]
# ## Variable delay model
#
# Now, to make this more complicated, we want to have varialbe delay. So, now, the goal is to transform a sequence of pairs (character, delay) into a character sequence with given delay. Delay is constant within one sequence.

# %% [markdown]
# ### Dataset
# As before, we first implement the dataset:

# %%
class VariableDelayEchoDataset(torch.utils.data.IterableDataset):

  def __init__(self, max_delay=8, seq_length=20, size=1000):
    self.max_delay = max_delay
    self.seq_length = seq_length
    self.size = size

  def __len__(self):
    return self.size

  def __iter__(self):
    for _ in range(self.size):
      seq = torch.tensor([random.choice(range(1, N + 1)) for i in range(self.seq_length)], dtype=torch.int64)
      delay = random.randint(0, self.max_delay)
      result = torch.cat((torch.zeros(delay), seq[:self.seq_length - delay])).type(torch.int64)
      yield seq, delay, result

# %% [markdown]
# ### Model
#
# And the model.

# %%
class VariableDelayGRUMemory(torch.nn.Module):
    def __init__(self, hidden_size, max_delay):
        super().__init__()
        self.max_delay = max_delay
        self.gru = torch.nn.GRU(hidden_size, hidden_size, batch_first=True)
        self.fc = torch.nn.Linear(hidden_size, N + 1)
        self.embed = torch.nn.Embedding(N + 1, hidden_size//2)
        self.delay_embed = torch.nn.Embedding(max_delay + 1, hidden_size//2)
        # self.dropout = torch.nn.Dropout(p=0.2)

    def forward(self, x, delays):
        x = self.embed(x)
        delays = self.delay_embed(delays).unsqueeze(1)
        delays = delays.repeat(1, x.shape[1], 1)
        x = torch.cat((delays, x), dim=2)

        x, _ = self.gru(x)

        # 应用 Dropout
        # x = self.dropout(x)

        x = self.fc(x)
        return x

    @torch.no_grad()
    def test_run(self, s, delay):
    # This function accepts one string s containing lowercase characters a-z,
    # and a delay - the desired output delay.
    # You need to map those characters to one-hot encodings,
    # then get the result from your network, and then convert the output
    # back to a string of the same length, with 0 mapped to ' ',
    # and 1-26 mapped to a-z.

    # TODO
      idx = [(ord(c) - ord('a') + 1) for c in s]
      idx_tensor = torch.tensor(idx, dtype=torch.long).unsqueeze(0)  # Convert list of indices to a long tensor and add batch dimension

      delay_tensor = torch.tensor([delay], dtype=torch.long)  # Make sure delay is also a long tensor

      logits = self.forward(idx_tensor, delay_tensor)  # Pass the indices and delays to the model
      pred = torch.argmax(logits, dim=2)  # Get predictions
      pred = pred.squeeze(0)  # Remove batch dimension for comparison

      # Convert predictions back to string
      pred_str = ''.join([' ' if c == 0 else chr(c + ord('a') - 1) for c in pred])

      return pred_str

# %% [markdown]
# ### Train
#
# As before, you're free to do what you want, as long as training finishes within 10 minutes and accuracy is above 0.99 for delays between 0 and 8.

# %%
def test_variable_delay_model(model, seq_length=20):
  """
  This is the test function that runs 100 different strings through your model,
  and checks the error rate.
  """
  total = 0
  correct = 0
  for i in range(500):
    s = ''.join([random.choice(string.ascii_lowercase) for i in range(seq_length)])
    d = random.randint(0, model.max_delay)
    result = model.test_run(s, d)
    if d > 0:
      z = zip(s[:-d], result[d:])
    else:
      z = zip(s, result)
    for c1, c2 in z:
      correct += int(c1 == c2)
    total += len(s) - d

  return correct / total

# %%
import time
import torch
from torch.utils.data import DataLoader

# 记录开始时间
start_time = time.time()

# 初始化参数
N = 26
hidden_size = 128  # 增加隐藏层大小
MAX_DELAY = 8
SEQ_LENGTH = 20
BATCH_SIZE = 64  # 减小批次大小
LR = 0.003  # 更小的初始学习率
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 初始化模型
model = VariableDelayGRUMemory(hidden_size=hidden_size, max_delay=MAX_DELAY).to(device)
criterion = torch.nn.CrossEntropyLoss(reduction='none').to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=LR)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[100, 200, 250], gamma=0.8)

# 训练循环
epoch = 0
accuracy = 0
while accuracy <= 0.993:
    dataset = VariableDelayEchoDataset(max_delay=MAX_DELAY, seq_length=SEQ_LENGTH, size=2000)
    dataloader = DataLoader(dataset, batch_size=BATCH_SIZE)

    model.train()  # 确保模型处于训练模式
    for seq, delay_val, result in dataloader:
        seq, delay_val, result = seq.to(device), delay_val.to(device), result.to(device)
        optimizer.zero_grad()

        outputs = model(seq.long(), delay_val)  # 确保seq是长整型张量

        # 使用pad_sequence创建掩码
        mask = [torch.zeros(d).to(device) for d in delay_val]
        mask.append(torch.zeros(SEQ_LENGTH).to(device))
        mask = torch.nn.utils.rnn.pad_sequence(mask, padding_value=1, batch_first=True)[:-1]

        outputs = outputs.reshape(-1, outputs.size(-1))
        loss = criterion(outputs, result.reshape(-1))
        loss = loss.reshape(-1, SEQ_LENGTH)
        loss = torch.mean(loss * mask, dim=1)
        loss = loss.mean()

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)  # 更小的梯度裁剪值
        optimizer.step()

    scheduler.step()  # 更新学习率
    model.eval()  # 确保模型处于评估模式
    accuracy = test_variable_delay_model(model)
    print(f"Epoch {epoch}, Accuracy: {accuracy:.4f}, Loss: {loss.mean().item():.4f}")
    epoch += 1

# 断言和测试
end_time = time.time()

assert end_time - start_time < 600, 'Executing took longer than 10 mins'
assert test_variable_delay_model(model) > 0.99, 'Accuracy is too low'
print('Tests passed')
# Out:
# Epoch 0, Accuracy: 0.2983, Loss: 1.5510
# Epoch 1, Accuracy: 0.4279, Loss: 1.4683
# Epoch 2, Accuracy: 0.4915, Loss: 1.0233
# Epoch 3, Accuracy: 0.5237, Loss: 1.1110
# Epoch 4, Accuracy: 0.5588, Loss: 1.1992
# Epoch 5, Accuracy: 0.5686, Loss: 0.8898
# Epoch 6, Accuracy: 0.5772, Loss: 0.7159
# Epoch 7, Accuracy: 0.6214, Loss: 0.6829
# Epoch 8, Accuracy: 0.6219, Loss: 0.6293
# Epoch 9, Accuracy: 0.6524, Loss: 0.7268
# Epoch 10, Accuracy: 0.6657, Loss: 0.6013
# Epoch 11, Accuracy: 0.6913, Loss: 0.7652
# Epoch 12, Accuracy: 0.6838, Loss: 0.8965
# Epoch 13, Accuracy: 0.7116, Loss: 0.6492
# Epoch 14, Accuracy: 0.7170, Loss: 0.5569
# Epoch 15, Accuracy: 0.7110, Loss: 0.4655
# Epoch 16, Accuracy: 0.7321, Loss: 0.6589
# Epoch 17, Accuracy: 0.7178, Loss: 0.4243
# Epoch 18, Accuracy: 0.7487, Loss: 0.4900
# Epoch 19, Accuracy: 0.7721, Loss: 0.5702
# Epoch 20, Accuracy: 0.7626, Loss: 0.3039
# Epoch 21, Accuracy: 0.7755, Loss: 0.5330
# Epoch 22, Accuracy: 0.7698, Loss: 0.4977
# Epoch 23, Accuracy: 0.7845, Loss: 0.5405
# Epoch 24, Accuracy: 0.7898, Loss: 0.5978
# Epoch 25, Accuracy: 0.7769, Loss: 0.3896
# Epoch 26, Accuracy: 0.7965, Loss: 0.5947
# Epoch 27, Accuracy: 0.7912, Loss: 0.3214
# Epoch 28, Accuracy: 0.7988, Loss: 0.3395
# Epoch 29, Accuracy: 0.8052, Loss: 0.3071
# Epoch 30, Accuracy: 0.8139, Loss: 0.2807
# Epoch 31, Accuracy: 0.8223, Loss: 0.3656
# Epoch 32, Accuracy: 0.8059, Loss: 0.4990
# Epoch 33, Accuracy: 0.8247, Loss: 0.3348
# Epoch 34, Accuracy: 0.8310, Loss: 0.3783
# Epoch 35, Accuracy: 0.8325, Loss: 0.1935
# Epoch 36, Accuracy: 0.8324, Loss: 0.4004
# Epoch 37, Accuracy: 0.8334, Loss: 0.3311
# Epoch 38, Accuracy: 0.8344, Loss: 0.2797
# Epoch 39, Accuracy: 0.8310, Loss: 0.4151
# Epoch 40, Accuracy: 0.8565, Loss: 0.3203
# Epoch 41, Accuracy: 0.8434, Loss: 0.4208
# Epoch 42, Accuracy: 0.8474, Loss: 0.3156
# Epoch 43, Accuracy: 0.8751, Loss: 0.2470
# Epoch 44, Accuracy: 0.8568, Loss: 0.3621
# Epoch 45, Accuracy: 0.8646, Loss: 0.2927
# Epoch 46, Accuracy: 0.8659, Loss: 0.2307
# Epoch 47, Accuracy: 0.8743, Loss: 0.2558
# Epoch 48, Accuracy: 0.8758, Loss: 0.3294
# Epoch 49, Accuracy: 0.8701, Loss: 0.3097
# Epoch 50, Accuracy: 0.8724, Loss: 0.2436
# Epoch 51, Accuracy: 0.8691, Loss: 0.2773
# Epoch 52, Accuracy: 0.8760, Loss: 0.3210
# Epoch 53, Accuracy: 0.8869, Loss: 0.2375
# Epoch 54, Accuracy: 0.8867, Loss: 0.2887
# Epoch 55, Accuracy: 0.8896, Loss: 0.1432
# Epoch 56, Accuracy: 0.8941, Loss: 0.1055
# Epoch 57, Accuracy: 0.9040, Loss: 0.2052
# Epoch 58, Accuracy: 0.8999, Loss: 0.1716
# Epoch 59, Accuracy: 0.8992, Loss: 0.3401
# Epoch 60, Accuracy: 0.8955, Loss: 0.2296
# Epoch 61, Accuracy: 0.8981, Loss: 0.1269
# Epoch 62, Accuracy: 0.9045, Loss: 0.2405
# Epoch 63, Accuracy: 0.8977, Loss: 0.3372
# Epoch 64, Accuracy: 0.9068, Loss: 0.1106
# Epoch 65, Accuracy: 0.9158, Loss: 0.3184
# Epoch 66, Accuracy: 0.9060, Loss: 0.2056
# Epoch 67, Accuracy: 0.9119, Loss: 0.1082
# Epoch 68, Accuracy: 0.9138, Loss: 0.2054
# Epoch 69, Accuracy: 0.9088, Loss: 0.2895
# Epoch 70, Accuracy: 0.9044, Loss: 0.1196
# Epoch 71, Accuracy: 0.9147, Loss: 0.2201
# Epoch 72, Accuracy: 0.9025, Loss: 0.0826
# Epoch 73, Accuracy: 0.9128, Loss: 0.2121
# Epoch 74, Accuracy: 0.9238, Loss: 0.3912
# Epoch 75, Accuracy: 0.9149, Loss: 0.2162
# Epoch 76, Accuracy: 0.9272, Loss: 0.1573
# Epoch 77, Accuracy: 0.9268, Loss: 0.1584
# Epoch 78, Accuracy: 0.9230, Loss: 0.1562
# Epoch 79, Accuracy: 0.9211, Loss: 0.1298
# Epoch 80, Accuracy: 0.9283, Loss: 0.2713
# Epoch 81, Accuracy: 0.9259, Loss: 0.0993
# Epoch 82, Accuracy: 0.9258, Loss: 0.1279
# Epoch 83, Accuracy: 0.9274, Loss: 0.1192
# Epoch 84, Accuracy: 0.9283, Loss: 0.1648
# Epoch 85, Accuracy: 0.9272, Loss: 0.1519
# Epoch 86, Accuracy: 0.9330, Loss: 0.0902
# Epoch 87, Accuracy: 0.9363, Loss: 0.1225
# Epoch 88, Accuracy: 0.9321, Loss: 0.1033
# Epoch 89, Accuracy: 0.9346, Loss: 0.2290
# Epoch 90, Accuracy: 0.9399, Loss: 0.0894
# Epoch 91, Accuracy: 0.9362, Loss: 0.0239
# Epoch 92, Accuracy: 0.9462, Loss: 0.1188
# Epoch 93, Accuracy: 0.9395, Loss: 0.1601
# Epoch 94, Accuracy: 0.9371, Loss: 0.2342
# Epoch 95, Accuracy: 0.9380, Loss: 0.1564
# Epoch 96, Accuracy: 0.9413, Loss: 0.2133
# Epoch 97, Accuracy: 0.9514, Loss: 0.1102
# Epoch 98, Accuracy: 0.9442, Loss: 0.0838
# Epoch 99, Accuracy: 0.9424, Loss: 0.1916
# Epoch 100, Accuracy: 0.9477, Loss: 0.0560
# Epoch 101, Accuracy: 0.9463, Loss: 0.0940
# Epoch 102, Accuracy: 0.9534, Loss: 0.0397
# Epoch 103, Accuracy: 0.9524, Loss: 0.1134
# Epoch 104, Accuracy: 0.9481, Loss: 0.0632
# Epoch 105, Accuracy: 0.9487, Loss: 0.1145
# Epoch 106, Accuracy: 0.9607, Loss: 0.0715
# Epoch 107, Accuracy: 0.9572, Loss: 0.1033
# Epoch 108, Accuracy: 0.9481, Loss: 0.1099
# Epoch 109, Accuracy: 0.9572, Loss: 0.0521
# Epoch 110, Accuracy: 0.9594, Loss: 0.0667
# Epoch 111, Accuracy: 0.9654, Loss: 0.0662
# Epoch 112, Accuracy: 0.9572, Loss: 0.1002
# Epoch 113, Accuracy: 0.9582, Loss: 0.1221
# Epoch 114, Accuracy: 0.9618, Loss: 0.1283
# Epoch 115, Accuracy: 0.9599, Loss: 0.0759
# Epoch 116, Accuracy: 0.9598, Loss: 0.0612
# Epoch 117, Accuracy: 0.9627, Loss: 0.0513
# Epoch 118, Accuracy: 0.9652, Loss: 0.1274
# Epoch 119, Accuracy: 0.9659, Loss: 0.0272
# Epoch 120, Accuracy: 0.9679, Loss: 0.1024
# Epoch 121, Accuracy: 0.9606, Loss: 0.0308
# Epoch 122, Accuracy: 0.9636, Loss: 0.1357
# Epoch 123, Accuracy: 0.9613, Loss: 0.0367
# Epoch 124, Accuracy: 0.9689, Loss: 0.0751
# Epoch 125, Accuracy: 0.9711, Loss: 0.1376
# Epoch 126, Accuracy: 0.9650, Loss: 0.0477
# Epoch 127, Accuracy: 0.9632, Loss: 0.1199
# Epoch 128, Accuracy: 0.9689, Loss: 0.0607
# Epoch 129, Accuracy: 0.9659, Loss: 0.0418
# Epoch 130, Accuracy: 0.9645, Loss: 0.0860
# Epoch 131, Accuracy: 0.9636, Loss: 0.0402
# Epoch 132, Accuracy: 0.9713, Loss: 0.1002
# Epoch 133, Accuracy: 0.9695, Loss: 0.0607
# Epoch 134, Accuracy: 0.9672, Loss: 0.0672
# Epoch 135, Accuracy: 0.9755, Loss: 0.0169
# Epoch 136, Accuracy: 0.9687, Loss: 0.0299
# Epoch 137, Accuracy: 0.9704, Loss: 0.1526
# Epoch 138, Accuracy: 0.9680, Loss: 0.0448
# Epoch 139, Accuracy: 0.9732, Loss: 0.0279
# Epoch 140, Accuracy: 0.9680, Loss: 0.1400
# Epoch 141, Accuracy: 0.9721, Loss: 0.1271
# Epoch 142, Accuracy: 0.9740, Loss: 0.0438
# Epoch 143, Accuracy: 0.9744, Loss: 0.1058
# Epoch 144, Accuracy: 0.9755, Loss: 0.0165
# Epoch 145, Accuracy: 0.9674, Loss: 0.0649
# Epoch 146, Accuracy: 0.9739, Loss: 0.1068
# Epoch 147, Accuracy: 0.9711, Loss: 0.1104
# Epoch 148, Accuracy: 0.9692, Loss: 0.0531
# Epoch 149, Accuracy: 0.9757, Loss: 0.0653
# Epoch 150, Accuracy: 0.9760, Loss: 0.0355
# Epoch 151, Accuracy: 0.9739, Loss: 0.0826
# Epoch 152, Accuracy: 0.9727, Loss: 0.0856
# Epoch 153, Accuracy: 0.9765, Loss: 0.0613
# Epoch 154, Accuracy: 0.9711, Loss: 0.0583
# Epoch 155, Accuracy: 0.9734, Loss: 0.0394
# Epoch 156, Accuracy: 0.9779, Loss: 0.0582
# Epoch 157, Accuracy: 0.9748, Loss: 0.0796
# Epoch 158, Accuracy: 0.9765, Loss: 0.0360
# Epoch 159, Accuracy: 0.9754, Loss: 0.0354
# Epoch 160, Accuracy: 0.9756, Loss: 0.0731
# Epoch 161, Accuracy: 0.9736, Loss: 0.1004
# Epoch 162, Accuracy: 0.9765, Loss: 0.0334
# Epoch 163, Accuracy: 0.9776, Loss: 0.0307
# Epoch 164, Accuracy: 0.9778, Loss: 0.0287
# Epoch 165, Accuracy: 0.9805, Loss: 0.0475
# Epoch 166, Accuracy: 0.9787, Loss: 0.0663
# Epoch 167, Accuracy: 0.9772, Loss: 0.0646
# Epoch 168, Accuracy: 0.9817, Loss: 0.0854
# Epoch 169, Accuracy: 0.9765, Loss: 0.0935
# Epoch 170, Accuracy: 0.9771, Loss: 0.0550
# Epoch 171, Accuracy: 0.9756, Loss: 0.0352
# Epoch 172, Accuracy: 0.9770, Loss: 0.0157
# Epoch 173, Accuracy: 0.9801, Loss: 0.0506
# Epoch 174, Accuracy: 0.9827, Loss: 0.0605
# Epoch 175, Accuracy: 0.9796, Loss: 0.0589
# Epoch 176, Accuracy: 0.9785, Loss: 0.0464
# Epoch 177, Accuracy: 0.9805, Loss: 0.0531
# Epoch 178, Accuracy: 0.9765, Loss: 0.0640
# Epoch 179, Accuracy: 0.9803, Loss: 0.0948
# Epoch 180, Accuracy: 0.9815, Loss: 0.0706
# Epoch 181, Accuracy: 0.9784, Loss: 0.0515
# Epoch 182, Accuracy: 0.9808, Loss: 0.0545
# Epoch 183, Accuracy: 0.9839, Loss: 0.0665
# Epoch 184, Accuracy: 0.9779, Loss: 0.0555
# Epoch 185, Accuracy: 0.9808, Loss: 0.0738
# Epoch 186, Accuracy: 0.9840, Loss: 0.0290
# Epoch 187, Accuracy: 0.9850, Loss: 0.0213
# Epoch 188, Accuracy: 0.9833, Loss: 0.0176
# Epoch 189, Accuracy: 0.9817, Loss: 0.0500
# Epoch 190, Accuracy: 0.9841, Loss: 0.0342
# Epoch 191, Accuracy: 0.9814, Loss: 0.0356
# Epoch 192, Accuracy: 0.9832, Loss: 0.0451
# Epoch 193, Accuracy: 0.9818, Loss: 0.0457
# Epoch 194, Accuracy: 0.9831, Loss: 0.0726
# Epoch 195, Accuracy: 0.9880, Loss: 0.0652
# Epoch 196, Accuracy: 0.9806, Loss: 0.0429
# Epoch 197, Accuracy: 0.9835, Loss: 0.0399
# Epoch 198, Accuracy: 0.9846, Loss: 0.0630
# Epoch 199, Accuracy: 0.9815, Loss: 0.0454
# Epoch 200, Accuracy: 0.9841, Loss: 0.0092
# Epoch 201, Accuracy: 0.9858, Loss: 0.0140
# Epoch 202, Accuracy: 0.9855, Loss: 0.0226
# Epoch 203, Accuracy: 0.9869, Loss: 0.0075
# Epoch 204, Accuracy: 0.9879, Loss: 0.0397
# Epoch 205, Accuracy: 0.9833, Loss: 0.0190
# Epoch 206, Accuracy: 0.9844, Loss: 0.0340
# Epoch 207, Accuracy: 0.9884, Loss: 0.0216
# Epoch 208, Accuracy: 0.9880, Loss: 0.0725
# Epoch 209, Accuracy: 0.9879, Loss: 0.0261
# Epoch 210, Accuracy: 0.9880, Loss: 0.0138
# Epoch 211, Accuracy: 0.9847, Loss: 0.0440
# Epoch 212, Accuracy: 0.9889, Loss: 0.0588
# Epoch 213, Accuracy: 0.9861, Loss: 0.0143
# Epoch 214, Accuracy: 0.9890, Loss: 0.0180
# Epoch 215, Accuracy: 0.9871, Loss: 0.0307
# Epoch 216, Accuracy: 0.9853, Loss: 0.0324
# Epoch 217, Accuracy: 0.9848, Loss: 0.0086
# Epoch 218, Accuracy: 0.9860, Loss: 0.0434
# Epoch 219, Accuracy: 0.9858, Loss: 0.0209
# Epoch 220, Accuracy: 0.9893, Loss: 0.0136
# Epoch 221, Accuracy: 0.9885, Loss: 0.0117
# Epoch 222, Accuracy: 0.9880, Loss: 0.0149
# Epoch 223, Accuracy: 0.9876, Loss: 0.0283
# Epoch 224, Accuracy: 0.9882, Loss: 0.0140
# Epoch 225, Accuracy: 0.9889, Loss: 0.0272
# Epoch 226, Accuracy: 0.9859, Loss: 0.0321
# Epoch 227, Accuracy: 0.9871, Loss: 0.0164
# Epoch 228, Accuracy: 0.9867, Loss: 0.0507
# Epoch 229, Accuracy: 0.9891, Loss: 0.0321
# Epoch 230, Accuracy: 0.9886, Loss: 0.0295
# Epoch 231, Accuracy: 0.9867, Loss: 0.0231
# Epoch 232, Accuracy: 0.9876, Loss: 0.0417
# Epoch 233, Accuracy: 0.9878, Loss: 0.0246
# Epoch 234, Accuracy: 0.9871, Loss: 0.0235
# Epoch 235, Accuracy: 0.9877, Loss: 0.0231
# Epoch 236, Accuracy: 0.9846, Loss: 0.0265
# Epoch 237, Accuracy: 0.9889, Loss: 0.0149
# Epoch 238, Accuracy: 0.9842, Loss: 0.0192
# Epoch 239, Accuracy: 0.9893, Loss: 0.0212
# Epoch 240, Accuracy: 0.9877, Loss: 0.0350
# Epoch 241, Accuracy: 0.9890, Loss: 0.0220
# Epoch 242, Accuracy: 0.9896, Loss: 0.0137
# Epoch 243, Accuracy: 0.9892, Loss: 0.0433
# Epoch 244, Accuracy: 0.9892, Loss: 0.0537
# Epoch 245, Accuracy: 0.9878, Loss: 0.0096
# Epoch 246, Accuracy: 0.9885, Loss: 0.0305
# Epoch 247, Accuracy: 0.9911, Loss: 0.0108
# Epoch 248, Accuracy: 0.9865, Loss: 0.0508
# Epoch 249, Accuracy: 0.9912, Loss: 0.0162
# Epoch 250, Accuracy: 0.9896, Loss: 0.0108
# Epoch 251, Accuracy: 0.9895, Loss: 0.0138
# Epoch 252, Accuracy: 0.9938, Loss: 0.0129
# Tests passed
